# %%
###default values
### mass : kg / lengh : au : km / time.period : sec / 
g=6.67384*1e-11*1e-9

m_solar = 1.989*1e30    
m_mercury = 3.3022*1e23
m_venus = 4.8690*1e24
m_earth = 5.9742*1e24
m_mars = 6.4191*1e23
m_jupiter = 1.8988*1e27
m_saturn = 5.6852*1e26
m_uranus = 8.6840*1e25
m_neptune = 1.0245*1e26
m_pluto = 1.3*1e22

d = 1.496*1e8 ###au km convert

r_solar = 0 *d
r_mercury = 0.39 *d
r_venus = 0.7 *d
r_earth = 1 *d
r_mars = 1.52 *d
r_jupiter = 5 *d
r_saturn = 10 *d
r_uranus = 20 *d
r_neptune = 30 *d
r_pluto = 39.48 *d

tt = 24*60*60  ###day hour minute seconde

t_mercury = 87.97 *tt
t_venus = 224.7 *tt
t_earth = 365.26 *tt
t_mars = 686.96 *tt
t_jupiter = 43333.29 *tt
t_saturn = 10756.20 *tt
t_uranus = 30707.49 *tt
t_neptune = 30225.35 *tt
t_pluto = 990623.31 *tt

# %%
import numpy as np
import matplotlib.pyplot as plt

###cartesian_newton   :x y vx vy m
t = 0
tt = 24*60*60

###solar:0 
x0=r_solar
y0=0
px0 = [x0]
py0 = [y0]
vx0=0
vy0=0
m0=m_solar

###mercury:1 
x1=r_mercury
y1=0
px1 = [x1]
py1 = [y1]
vx1=0
vy1=r_mercury*2*np.pi/t_mercury
m1=m_mercury

###venus:2  
x2=r_venus
y2=0
px2 = [x2]
py2 = [y2]
vx2=0
vy2=r_venus*2*np.pi/t_venus
m2=m_venus

### earth:3 
x3=r_earth
y3=0
px3 = [x3]
py3 = [y3]
vx3=0
vy3=r_earth*2*np.pi/t_earth
m3=m_earth

### mars:4 
x4=r_mars
y4=0
px4 = [x4]
py4 = [y4]
vx4=0
vy4=r_mars*2*np.pi/t_mars
m4=m_mars

###jupiter:5
x5=r_jupiter
y5=0
px5 = [x5]
py5 = [y5]
vx5=0
vy5=r_jupiter*2*np.pi/t_jupiter
m5=m_jupiter

###saturn:6
x6=r_saturn
y6=0
px6 = [x6]
py6 = [y6]
vx6=0
vy6=r_saturn*2*np.pi/t_saturn
m6=m_saturn

### uranus:7 
x7=r_uranus
y7=0
px7 = [x7]
py7 = [y7]
vx7=0
vy7=r_uranus*2*np.pi/t_uranus
m7=m_uranus

### neptune:8 
x8=r_neptune
y8=0
px8 = [x8]
py8 = [y8]
vx8=0
vy8=r_neptune*2*np.pi/t_neptune
m8=m_neptune

### pluto:9
x9=r_pluto
y9=0
px9 = [x9]
py9 = [y9]
vx9=0
vy9=r_pluto*2*np.pi/t_pluto
m9=m_pluto

print(t,"\n solar x",x0,"y",y0,"\n mercury x",x1,"y",y1,"\n venus x",x2,"y",y2,"\n earth x",x3,"y",y3,"\n mars x",x4,"y",y4,"\n jupiter x",x5,"y",y5,"\n saturn x",x6,"y",y6,"\n uranus x",x7,"y",y7,"\n neptune x",x8,"y",y8,"\n pluto x",x9,"y",y9,"\n \n")
# Out:
# 0
#  solar x 0.0 y 0
#  mercury x 58344000.0 y 0
#  venus x 104720000.0 y 0
#  earth x 149600000.0 y 0
#  mars x 227392000.0 y 0
#  jupiter x 748000000.0 y 0
#  saturn x 1496000000.0 y 0
#  uranus x 2992000000.0 y 0
#  neptune x 4488000000.0 y 0
#  pluto x 5906208000.0 y 0

# %%
while t <= t_earth :
    t = t+tt
    x1 = x1 + vx1*tt
    y1 = y1 + vy1*tt
    vx1 =vx1+ ((g*m0*m1*abs(x0-x1)/(x0-x1)**3)/m1)*1
    vy1 =vy1+ ((g*m0*m1*abs(y0-y1)/(y0-y1)**3)/m1)*1
    px1.insert(1,x1)
    py1.insert(1,y1)

    x2 = x2 + vx2*tt
    y2 = y2 + vy2*tt
    vx2 =vx2+ ((g*m0*m2*abs(x0-x2)/(x0-x2)**3)/m2)*1
    vy2 =vy2+ ((g*m0*m2*abs(y0-y2)/(y0-y2)**3)/m2)*1
    px2.insert(1,x2)
    py2.insert(1,y2)
    
    x3 = x3 + vx3*tt
    y3 = y3 + vy3*tt
    vx3 =vx3+ ((g*m0*m3*abs(x0-x3)/(x0-x3)**3)/m3)*1
    vy3 =vy3+ ((g*m0*m3*abs(y0-y3)/(y0-y3)**3)/m3)*1
    px3.insert(1,x3)
    py3.insert(1,y3)
    
    x4 = x4 + vx4*tt
    y4 = y4 + vy4*tt
    vx4 =vx4+ ((g*m0*m4*abs(x0-x4)/(x0-x4)**3)/m4)*1
    vy4 =vy4+ ((g*m0*m4*abs(y0-y4)/(y0-y4)**3)/m4)*1
    px4.insert(1,x4)
    py4.insert(1,y4)
    
    x5 = x5 + vx5*tt
    y5 = y5 + vy5*tt
    vx5 =vx5+ ((g*m0*m5*abs(x0-x5)/(x0-x5)**3)/m5)*1
    vy5 =vy5+ ((g*m0*m5*abs(y0-y5)/(y0-y5)**3)/m5)*1
    px5.insert(1,x5)
    py5.insert(1,y5)
    
    x6 = x6 + vx6*tt
    y6 = y6 + vy6*tt
    vx6 =vx6+ ((g*m0*m6*abs(x0-x6)/(x0-x6)**3)/m6)*1
    vy6 =vy6+ ((g*m0*m6*abs(y0-y6)/(y0-y6)**3)/m6)*1
    px6.insert(1,x6)
    py6.insert(1,y6)
    
    x7 = x7 + vx7*tt
    y7 = y7 + vy7*tt
    vx7 =vx7+ ((g*m0*m7*abs(x0-x7)/(x0-x7)**3)/m7)*1
    vy7 =vy7+ ((g*m0*m7*abs(y0-y7)/(y0-y7)**3)/m7)*1
    px7.insert(1,x7)
    py7.insert(1,y7)
    
    x8 = x8 + vx8*tt
    y8 = y8 + vy8*tt
    vx8 =vx8+ ((g*m0*m8*abs(x0-x8)/(x0-x8)**3)/m8)*1
    vy8 =vy8+ ((g*m0*m8*abs(y0-y8)/(y0-y8)**3)/m8)*1
    px8.insert(1,x8)
    py8.insert(1,y8)
    
    x9 = x9 + vx9*tt
    y9 = y9 + vy9*tt
    vx9 =vx9+ ((g*m0*m9*abs(x0-x9)/(x0-x9)**3)/m9)*1
    vy9 =vy9+ ((g*m0*m9*abs(y0-y9)/(y0-y9)**3)/m9)*1
    px9.insert(1,x9)
    py9.insert(1,y9)
    
    print(t,"\n solar x",x0,"y",y0,"\n mercury x",x1,"y",y1,"\n venus x",x2,"y",y2,"\n earth x",x3,"y",y3,"\n mars x",x4,"y",y4,"\n jupiter x",x5,"y",y5,"\n saturn x",x6,"y",y6,"\n uranus x",x7,"y",y7,"\n neptune x",x8,"y",y8,"\n pluto x",x9,"y",y9,"\n \n")
    
###for t in range(1,t_earth) :
fig = plt.figure(figsize=(100,100))

plt.plot(px0, py0 ,'*r')
plt.plot(px1, py1 ,'ob')
plt.plot(px2, py2 ,'og')
plt.plot(px3, py3 ,'*g')
plt.plot(px4, py4 ,'or')
plt.plot(px5, py5 ,'oc')
plt.plot(px6, py6 ,'om')
plt.plot(px7, py7 ,'oy')
plt.plot(px8, py8 ,'ok')
plt.plot(px9, py9 ,'*k')

plt.suptitle("position")
# Out:
# 86400
#  solar x 0.0 y 0
#  mercury x 58344000.0 y 4167172.4856438083
#  venus x 104720000.0 y 2928238.3861497384
#  earth x 149600000.0 y 2573412.150123381
#  mars x 227392000.0 y 2079809.7027049323
#  jupiter x 748000000.0 y 108457.55329840707
#  saturn x 1496000000.0 y 873881.5956881297
#  uranus x 2992000000.0 y 612205.3752710274
#  neptune x 4488000000.0 y 932956.4639821204
#  pluto x 5906208000.0 y 37461.06007413305
#
#
# 172800
#  solar x 0.0 y 0
#  mercury x 58343996.63076025 y 8333684.51913153
#  venus x 104719998.95416048 y 5855139.217890637
#  earth x 149599999.48753864 y 5145092.468797502
#  mars x 227391999.77819365 y 4156967.9940278134
#  jupiter x 747999999.9795015 y -758085.1058355102
#  saturn x 1495999999.9948754 y 1732744.948270131
#  uranus x 2991999999.9987187 y 1193810.1436872259
#  neptune x 4487999999.999431 y 1852736.3826447562
#  pluto x 5906207999.999671 y -8097752.156868221
#
#
# 259200
#  solar x 0.0 y 0
# ...
